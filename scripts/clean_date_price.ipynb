# %%
import pandas as pd

# %%
yam_price = pd.read_csv('unclean_price_date.csv', index_col=0)

# %%
yam_price.head()
# Out:
#      DAY  MONTH   PRICE  Year        DATE
# 0      1      1  0.0032  1970  1970-01-01
# 48     1      2  0.0031  1970  1970-02-01
# 96     1      3  0.0035  1970  1970-03-01
# 144    1      4  0.0037  1970  1970-04-01
# 192    1      5  0.0040  1970  1970-05-01

# %%
yam_price = yam_price.set_index('DATE')

# %%
yam_price = yam_price.drop(['DAY','MONTH','Year'], axis=1)

# %%
yam_price.head()
# Out:
#              PRICE
# DATE
# 1970-01-01  0.0032
# 1970-02-01  0.0031
# 1970-03-01  0.0035
# 1970-04-01  0.0037
# 1970-05-01  0.0040

# %%
yam_price.tail()
# Out:
#              PRICE
# DATE
# 2017-08-01  524.45
# 2017-09-01  482.71
# 2017-10-01  447.24
# 2017-11-01  462.33
# 2017-12-01  461.76

# %%
yam_price
# Out:
#                PRICE
# DATE
# 1970-01-01    0.0032
# 1970-02-01    0.0031
# 1970-03-01    0.0035
# 1970-04-01    0.0037
# 1970-05-01    0.0040
# 1970-06-01    0.0039
# 1970-07-01    0.0036
# 1970-08-01    0.0037
# 1970-09-01    0.0031
# 1970-10-01    0.0030
# 1970-11-01    0.0033
# 1970-12-01    0.0035
# 1971-01-01    0.0037
# 1971-02-01    0.0039
# 1971-03-01    0.0040
# 1971-04-01    0.0034
# 1971-05-01    0.0051
# 1971-06-01    0.0054
# 1971-07-01    0.0039
# 1971-08-01    0.0034
# 1971-09-01    0.0030
# 1971-10-01    0.0030
# 1971-11-01    0.0034
# 1971-12-01    0.0042
# 1972-01-01    0.0038
# 1972-02-01    0.0044
# 1972-03-01    0.0045
# 1972-04-01    0.0051
# 1972-05-01    0.0061
# 1972-06-01    0.0065
# ...              ...
# 2015-07-01  376.9300
# 2015-08-01  368.4000
# 2015-09-01  301.0400
# 2015-10-01  309.4400
# 2015-11-01  327.2500
# 2015-12-01  345.1700
# 2016-01-01  375.1300
# 2016-02-01  382.9800
# 2016-03-01  423.6300
# 2016-04-01  473.1000
# 2016-05-01  524.8900
# ...

# %%
yam_price = yam_price.to_csv('final_date_price_yam.csv')
