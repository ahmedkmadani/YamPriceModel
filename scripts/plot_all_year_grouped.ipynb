# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
yam_all_years = pd.read_csv('yam_all_year.csv')

# %%
yam_all_years
# Out:
#     Unnamed: 0       Year    1970    1971    1972    1973    1974    1975  \
# 0            0    JANUARY  0.0032  0.0037  0.0038  0.0045  0.0068  0.0083
# 1            1   FEBRUARY  0.0031  0.0039  0.0044  0.0053  0.0070  0.0088
# 2            2      MARCH  0.0035  0.0040  0.0045  0.0057  0.0075  0.0090
# 3            3      APRIL  0.0037  0.0034  0.0051  0.0060  0.0077  0.0089
# 4            4        MAY  0.0040  0.0051  0.0061  0.0067  0.0081  0.0106
# 5            5       JUNE  0.0039  0.0054  0.0065  0.0067  0.0090  0.0099
# 6            6       JULY  0.0036  0.0039  0.0041  0.0055  0.0070  0.0093
# 7            7     AUGUST  0.0037  0.0034  0.0035  0.0047  0.0057  0.0071
# 8            8  SEPTEMBER  0.0031  0.0030  0.0031  0.0043  0.0053  0.0073
# 9            9    OCTOBER  0.0030  0.0030  0.0035  0.0042  0.0056  0.0157
# 10          10   NOVEMBER  0.0033  0.0034  0.0041  0.0054  0.0066  0.0089
# 11          11   DECEMBER  0.0035  0.0042  0.0044  0.0063  0.0073  0.0105
#
# ...

# %%
yam_all_years[-12:].plot(x='Year', y=['1970','1971','1972','1973','1974','1975'], figsize=(15,10), rot=0)

# %%
yam_all_years.plot(x='Year', y=['1976','1977','1978','1979','1980'], figsize=(15,10), rot=0)

# %%
yam_all_years.plot(x='Year', y=['1981','1982','1983','1984','1985'], figsize=(15,10), rot=0)

# %%
yam_all_years.plot(x='Year', y=['1986','1987','1988','1989','1990'], figsize=(15,10), rot=0)

# %%
yam_all_years.plot(x='Year', y=['1991','1992','1993','1994','1995'], figsize=(15,10), rot=0)

# %%
yam_all_years.plot(x='Year', y=['1996','1997','1998','1999','2000'], figsize=(15,10), rot=0)

# %%
yam_all_years.plot(x='Year', y=['2001','2002','2003','2005','2006'], figsize=(15,10), rot=0)

# %%
yam_all_years.plot(x='Year', y=['2007','2008','2009','2010','2011'], figsize=(15,10), rot=0)

# %%
yam_all_years.plot(x='Year', y=['2012','2013','2014','2015','2016','2017'], figsize=(15,10), rot=0)
